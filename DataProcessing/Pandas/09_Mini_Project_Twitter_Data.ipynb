# %%
import numpy as np
import pandas as pd
import tweepy
import os

# %% [markdown]
# ### connect to API

# %%
CONSUMER_KEY = os.environ['CONSUMER_KEY']
CONSUMER_SECRET = os.environ['CONSUMER_SECRET']
ACCESS_TOKEN = os.environ['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = os.environ['ACCESS_TOKEN_SECRET']
BEARER_TOKEN = os.environ['BEARER_TOKEN']

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### Extracting Data

# %%
def scrape(words, date_since, numtweet) :
    tweets = tweepy.Cursor(
        api.search_tweets,
        words,
        lang='en',
        since_id=date_since,
        tweet_mode='extended',
    ).items(numtweet)
    
    return tweets

# %%
tweets = scrape(
    words='MahsaAmini',
    date_since='2022-09-30',
    numtweet=100,
)

# %%
list_tweets = {tweet for tweet in tweets}

# %%
df = pd.DataFrame(
    {},
    columns=
    [
        'username',
        'description',
        'location',
        'following',
        'followers',
        'totaltweets',
        'retweetcount',
        'text',
        'hashtags',
    ]
)
df
# Out:
# Empty DataFrame
# Columns: [username, description, location, following, followers, totaltweets, retweetcount, text, hashtags]
# Index: []

# %%
def concater(df,
            username, description, location, following,
            followers, totaltweets, retweetcount,
            text=None, hashtags=None) :
    
    return pd.concat([df, 
               pd.DataFrame([
                {
                'username': username,
                'description': description,
                'location': location,
                'following': following,
                'followers': followers,
                'totaltweets': totaltweets,
                'retweetcount': retweetcount,
                'text': text,
                'hashtags': hashtags,
                }
            ]   
        )
    ]
)

# %%
for tweet in list_tweets:
    try : 
        text=tweet.retweeted_status.full_text
    except AttributeError:
        text = None
        
    df = concater(
        df,
        username=tweet.user.screen_name,
        description=tweet.user.description,
        location=tweet.user.location,
        following=tweet.user.friends_count,
        followers=tweet.user.followers_count,
        totaltweets=tweet.user.statuses_count ,
        retweetcount=tweet.retweet_count,
        text=text,
        hashtags=tweet.entities['hashtags']
    )

# %%
df.index = range(100)

# %%
df.to_csv('./twitterData.csv')

# %%
df.head()
# Out:
#           username  \
# 0  Yasminjederzeit
# 1   mohammdali1988
# 2      Sauroniops1
# 3       Rose_zhina
# 4       ChewyBirdd
#
#                                                                                            description  \
# 0
# 1  EX-Student of Tehran University- I active for a #freeIran \nPro-PMOI/MEK https://t.co/4WCealWJY3...
# 2
# 3
# 4                                                                                               ایران🖤
#
#   location following followers totaltweets retweetcount  \
# 0                 27        11          91         4818
# 1                663       305       44620           35
# 2                189        17        3506         2770
# 3                  3        11         647           20
# 4                261        33        2695          759
#
#                                                                                                   text  \
# 0  .@nytimes What’s going on, guys?\n#IranProtests #SharifUniversity #IranRevolution #MahsaAmini ht...
# 1  October 3 - Tehran, #Iran \nFerdows Boulevard\nHigh school students chanting: "Death to the dict...
# 2  This the image &amp; voice of the new Iran! Highschool girls singing #ShervinHajipour's song wit...
# 3  Pt.1\nRIP @Coolio who inspired me to make this video\n#MahsaAmini #Oplran #مهسا_امینی #اعتصابات_...
# 4  They are killing the classmates of the first American woman ever to have won a Fields Medal. Ser...
#
#                                                                                               hashtags
# 0  [{'text': 'IranProtests', 'indices': [50, 63]}, {'text': 'SharifUniversity', 'indices': [64, 81]...
# 1         [{'text': 'Iran', 'indices': [38, 43]}, {'text': 'IranProtests2022', 'indices': [119, 136]}]
# 2                                                  [{'text': 'ShervinHajipour', 'indices': [88, 104]}]
# 3  [{'text': 'MahsaAmini', 'indices': [68, 79]}, {'text': 'Oplran', 'indices': [80, 87]}, {'text': ...
# 4                                                                                                   []

# %%
df['followers'] = df['followers'].apply(
    lambda x: np.NaN if x==0 else x)

# %%
df
# Out:
#            username  \
# 0   Yasminjederzeit
# 1    mohammdali1988
# 2       Sauroniops1
# 3        Rose_zhina
# 4        ChewyBirdd
# ..              ...
# 95   mohammdali1988
# 96      theAnt_Man1
# 97     sooriiaannaa
# 98    lonlyowl_Iran
# 99   michelbenard87
#
#                                                                                             description  \
# 0
# 1   EX-Student of Tehran University- I active for a #freeIran \nPro-PMOI/MEK https://t.co/4WCealWJY3...
# 2
# 3
# 4                                                                                                ایران🖤
# ..                                                                                                  ...
# 95  EX-Student of Tehran University- I active for a #freeIran \nPro-PMOI/MEK https://t.co/4WCealWJY3...
# 96         U.S. Army 🪖 vet,love my dogs \nDonald Dumpf and Putin are scum.\n 🌊 👋Vote blue 🌊🌊 Atheist ⚛️
# 97
# 98
# 99                                                     l'OM reste le plus grand club Français dixit Leo
#
#                   location following  followers totaltweets retweetcount  \
# 0                                 27       11.0          91         4818
# 1                                663      305.0       44620           35
# 2                                189       17.0        3506         2770
# 3                                  3       11.0         647           20
# 4                                261       33.0        2695          759
# ..                     ...       ...        ...         ...          ...
# 95                               663      305.0       44620           28
# 96             Nevada, USA       723      342.0        4609          963
# 97                                53        4.0        1424          760
# 98                                23        NaN         210         2050
# 99  Lignan-sur-Orb, France       823      314.0       14200          934
#
#                                                                                                    text  \
# 0   .@nytimes What’s going on, guys?\n#IranProtests #SharifUniversity #IranRevolution #MahsaAmini ht...
# 1   October 3 - Tehran, #Iran \nFerdows Boulevard\nHigh school students chanting: "Death to the dict...
# 2   This the image &amp; voice of the new Iran! Highschool girls singing #ShervinHajipour's song wit...
# 3   Pt.1\nRIP @Coolio who inspired me to make this video\n#MahsaAmini #Oplran #مهسا_امینی #اعتصابات_...
# 4   They are killing the classmates of the first American woman ever to have won a Fields Medal. Ser...
# ..                                                                                                  ...
# 95  October 3 - Urmia, northwest #Iran \nUrmia University students protesting and chanting: "Politic...
# 96  They are shooting students at Sharif University in Tehran. \n\nPlease let the world know! \n\n#M...
# 97  They are killing the classmates of the first American woman ever to have won a Fields Medal. Ser...
# 98  Dear @POTUS administration, if you send billions of dollars to prop up this murderous regime, hi...
# 99  Women waving their headscarves in the middle of Tehran’s main Vali Asr St. on Oct 1. #Iran #Mahs...
#
#                                                                                                hashtags
# 0   [{'text': 'IranProtests', 'indices': [50, 63]}, {'text': 'SharifUniversity', 'indices': [64, 81]...
# 1          [{'text': 'Iran', 'indices': [38, 43]}, {'text': 'IranProtests2022', 'indices': [119, 136]}]
# 2                                                   [{'text': 'ShervinHajipour', 'indices': [88, 104]}]
# 3   [{'text': 'MahsaAmini', 'indices': [68, 79]}, {'text': 'Oplran', 'indices': [80, 87]}, {'text': ...
# 4                                                                                                    []
# ..                                                                                                  ...
# 95                                                              [{'text': 'Iran', 'indices': [47, 52]}]
# 96       [{'text': 'MahsaAmini', 'indices': [102, 113]}, {'text': 'ZhinaAmini', 'indices': [114, 125]}]
# 97                                                                                                   []
# 98                                                                                                   []
# 99  [{'text': 'Iran', 'indices': [96, 101]}, {'text': 'MahsaAmini', 'indices': [102, 113]}, {'text':...
#
# [100 rows x 9 columns]

# %% [markdown]
# ___
